# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import hist

# %%
f=uproot.open("/home/submit/chowb/fccee/FCCAnalyzer/tmp/output_xsec_example.root")

# %%
f.keys()
# Out:
# ['p8_ee_Zmumu_ecm91;1',
#  'p8_ee_Zmumu_ecm91/leps_all_p;1',
#  'p8_ee_Zmumu_ecm91/leps_all_theta;1',
#  'p8_ee_Zmumu_ecm91/leps_all_phi;1',
#  'p8_ee_Zmumu_ecm91/leps_all_q;1',
#  'p8_ee_Zmumu_ecm91/leps_all_no;1',
#  'p8_ee_Zmumu_ecm91/m_inv;1',
#  'p8_ee_Zmumu_ecm91/emiss;1',
#  'p8_ee_Zmumu_ecm91/meta;1',
#  'p8_ee_Ztautau_ecm91;1',
#  'p8_ee_Ztautau_ecm91/leps_all_p;1',
#  'p8_ee_Ztautau_ecm91/leps_all_theta;1',
#  'p8_ee_Ztautau_ecm91/leps_all_phi;1',
#  'p8_ee_Ztautau_ecm91/leps_all_q;1',
#  'p8_ee_Ztautau_ecm91/leps_all_no;1',
#  'p8_ee_Ztautau_ecm91/m_inv;1',
#  'p8_ee_Ztautau_ecm91/emiss;1',
#  'p8_ee_Ztautau_ecm91/meta;1']

# %%
h = f['p8_ee_Zmumu_ecm91/leps_all_p;1']
print(h)

y,x = h.to_numpy()

plt.plot(x[:-1],y, color='cornflowerblue')
plt.xlim(0,50)
plt.yscale("log")
plt.plot ([45,45], [1e-2,1e7], linestyle='dashed', color ='lightsteelblue', label=('m_Z/2'))
plt.legend()
# Out:
# <TH1D (version 3) at 0x7fce23016b90>

# %%
h = f['p8_ee_Zmumu_ecm91/leps_all_q;1']
print(h)

y,x = h.to_numpy()

plt.plot(x[:-1],y, color='cornflowerblue')
plt.xlim(-5,5)
plt.yscale("log")
# Out:
# <TH1D (version 3) at 0x7fce22ea4e10>

# %%
h = f['p8_ee_Zmumu_ecm91/leps_all_no;1']
print(h)

y,x = h.to_numpy()

plt.scatter(x[:-1],y, color='cornflowerblue')
plt.xlim(0, 5)
# Out:
# <TH1D (version 3) at 0x7fce218fe490>
# (0.0, 5.0)

# %%
h = f['p8_ee_Zmumu_ecm91/leps_all_theta;1']
print(h)

y,x = h.to_numpy()

plt.plot(x[:-1],y, color='cornflowerblue')
plt.xlim(0, 3.1)
plt.yscale("log")
# Out:
# <TH1D (version 3) at 0x7fce21906310>

# %%
f=uproot.open("/home/submit/chowb/fccee/FCCAnalyzer/tmp/output_xsec_example.root")

h = f['p8_ee_Zmumu_ecm91/leps_all_no;1']

y,x = h.to_numpy()

plt.plot(x[:-1],y, color='palevioletred', drawstyle='steps-mid')

plt.xlim(0,5)
plt.yscale("log")

# %%
h = f['p8_ee_Zmumu_ecm91/m_inv;1']

y1,x = h.to_numpy()
plt.plot(x[:-1],y1, color='palevioletred', drawstyle='steps-mid', label='mumu')
integral = sum(y1)
print(integral)


plt.xlim(-5,100)
plt.yscale("log")
plt.legend()
# Out:
# 201780220651.20004

# %%
h = f['p8_ee_Ztautau_ecm91/m_inv;1']

y2,x = h.to_numpy()

plt.plot(x[:-1],y2, color='palevioletred', drawstyle='steps-mid', label='tautau')
integral = sum(y2)
print(integral)

plt.xlim(-5,100)
plt.yscale("log")
plt.legend()
# Out:
# 5471083279.199961

# %%
plt.plot(x[:-1],y1, color='lightsteelblue', drawstyle='steps-mid', label="mumu")
plt.plot(x[:-1],y2, color='lightpink', drawstyle='steps-mid', label="tautau")

plt.xlim(40,100)
plt.yscale("log")
plt.plot([50,50],[1e-2,1e7], color='dimgrey', linestyle='dashed')
plt.legend()

integral_total = sum(y1)+sum(y2)
print(integral_total)
# Out:
# 207251303930.4

# %%
plt.plot(x[:-1], y1/sum(y1), color='lightsteelblue', drawstyle='steps-mid', label="mumu")
plt.plot(x[:-1], y2/sum(y2), color='lightpink', drawstyle='steps-mid', label="tautau")
plt.yscale("log")
plt.xlim(45,100)
plt.title("normalization")
plt.legend()

# %%
ax = plt.gca()
ax.set_facecolor('dimgray')

# %%
h = f['p8_ee_Zmumu_ecm91/emiss;1']

y3,x = h.to_numpy()

plt.plot(x[:-1],y3, color='palevioletred', drawstyle='steps-mid', label='emiss_mumu')
plt.xlim(-5,100)
plt.title("missing energy: mumu")
plt.yscale("log")
plt.legend()

# %%
h = f['p8_ee_Ztautau_ecm91/emiss;1']

y4,x = h.to_numpy()

plt.plot(x[:-1],y4, color='palevioletred', drawstyle='steps-mid', label='emiss_tautau')
plt.xlim(-5,100)
plt.title("missing energy: tautau")
plt.yscale("log")
plt.legend()

# %%
plt.plot(x[:-1],y3, color='lightsteelblue', drawstyle='steps-mid', label="emiss_mumu")
plt.plot(x[:-1],y4, color='lightpink', drawstyle='steps-mid', label="emiss_tautau")

plt.xlim(-5,100)
plt.yscale("log")
plt.legend()

plt.plot([23,23],[1e-2,1e7], color='dimgrey', linestyle='dashed')

# %%
plt.plot(x[:-1],y1, color='mediumseagreen', drawstyle='steps-mid', label="mumu")
plt.plot(x[:-1],y2, color='tan', drawstyle='steps-mid', label="tautau")

plt.xlim(-5,100)
plt.yscale("log")
plt.ylim(0,10e7)
plt.plot([75.3225,75.3225],[1e-2,1e7], color='dimgrey', linestyle='dashed')
plt.legend()

integral_total = sum(y1)+sum(y2)
print(integral_total)    

domain = np.arange(start=50, stop=100)
print(domain)

ratio = sum(y1, start = 80)/(np.sqrt(sum(y1, start = 80)+sum(y2, start = 80)))
print(ratio)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 plt.plot(x[:-1],y1, color='mediumseagreen', drawstyle='steps-mid', label="mumu")
#       2 plt.plot(x[:-1],y2, color='tan', drawstyle='steps-mid', label="tautau")
#       4 plt.xlim(-5,100)
#
# File /work/submit/chowb/miniforge3/envs/fcc/lib/python3.11/site-packages/matplotlib/pyplot.py:2740, in plot(scalex, scaley, data, *args, **kwargs)
#    2738 @_copy_docstring_and_deprecators(Axes.plot)
#    2739 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2740     return gca().plot(
#    2741         *args, scalex=scalex, scaley=scaley,
#    2742         **({"data": data} if data is not None else {}), **kwargs)
#
# File /work/submit/chowb/miniforge3/envs/fcc/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1662, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1419 """
#    1420 Plot y versus x as lines and/or markers.
#    1421
#    (...)
#    1659 (``'green'``) or hex strings (``'#008000'``).
#    1660 """
#    1661 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1662 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1663 for line in lines:
#    1664     self.add_line(line)
#
# File /work/submit/chowb/miniforge3/envs/fcc/lib/python3.11/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File /work/submit/chowb/miniforge3/envs/fcc/lib/python3.11/site-packages/matplotlib/axes/_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (1000,) and (20000,)

# %%
y5 = sum(y1)/(np.sqrt(sum(y1)+sum(y2)))
y5,x = h.to_numpy()
plt.plot(x[:-1],y5)
